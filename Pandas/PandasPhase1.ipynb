# %% [markdown]
# Creation of Data Frames, Exploring Data

# %%
import pandas as pd

# %% [markdown]
# ### DataFrames

# %%
student = {
    'id':['S2601','S2602','S2603','S2604'],
    'name':['abc','def','ghi','jkl'],
    'age':[19,20,21,22]
}
#Creation of dataframe
df = pd.DataFrame(student)
df
# Out:
#       id name  age
# 0  S2601  abc   19
# 1  S2602  def   20
# 2  S2603  ghi   21
# 3  S2604  jkl   22

# %%
#Shape
df.shape
#Size
df.size
#Columns
df.columns
#Rename
df.rename(columns={"id":"student_id"},inplace=True)
df
# Out:
#   student_id name  age
# 0      S2601  abc   19
# 1      S2602  def   20
# 2      S2603  ghi   21
# 3      S2604  jkl   22

# %%
df
# Out:
#   student_id name  age
# 0      S2601  abc   19
# 1      S2602  def   20
# 2      S2603  ghi   21
# 3      S2604  jkl   22

# %% [markdown]
# ### Export to CSV file

# %%
df.to_csv("student_data.csv",index = False)

# %% [markdown]
# ### Import CSV file

# %%
#Same folder
df = pd.read_csv("companydemo.csv")
df
#Diff Folder
df1 = pd.read_csv("F:/Python-DataScience/Pandas/subdata_pandas/student.csv")
df1
# Out:
#     id             name  age  marks   fees
# 0  101    Akshay Shetty   20     85  25000
# 1  102       Ananya Rao   21     92  30000
# 2  103   Rohit Bhandary   19     76  28000
# 3  104    Nisha D'Souza   20     88  25000
# 4  105  Karthik Poojary   22     69  32000
# 5  106    Shreya Shetty   19     95  30000
# 6  107       Rohan Naik   21     72  27000
# 7  108     Deepika Bhat   20     81  28000
# 8  109  Abhishek Kotian   22     64  26000
# 9  110        Pooja Rai   19     90  30000

# %% [markdown]
# ### Import Excel File

# %%
df = pd.read_excel("subdata_pandas/expense.xlsx")
df
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04        Food              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %% [markdown]
# ### Exploring Data

# %%
df = pd.read_csv("subdata_pandas/employee.csv")
df
# Out:
#       id  gender dateofbirth  education   department  salary  starting_salary  \
# 0      1    Male  03-02-1952         15           IT   57000            27000
# 1      2    Male  23-05-1958         16           IT   40200            18750
# 2      3  Female  26-07-1929         12      Finance   21450            12000
# 3      4  Female  15-04-1947         18           IT   21900            13200
# 4      5    Male  09-02-1955         15      Finance   45000            21000
# ..   ...     ...         ...        ...          ...     ...              ...
# 469  470    Male  22-01-1964         12           IT   26250            15750
# 470  471    Male  03-08-1966         15  Engineering   26400            15750
# 471  472    Male  21-02-1966         15        Sales   39150            15750
# 472  473  Female  25-11-1937         12    Marketing   21450            12750
# 473  474  Female  05-11-1968         12           IT   29400            14250
#
# ...

# %%
#Top 10 rows
df.head(10)

#Last 10 rows
df.tail(10)

#Shape
df.shape

#Size
df.size

#Info
df.info()

#Describe
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   474 non-null    int64
#  1   gender               474 non-null    object
#  2   dateofbirth          473 non-null    object
#  3   education            474 non-null    int64
#  4   department           474 non-null    object
#  5   salary               474 non-null    int64
#  6   starting_salary      474 non-null    int64
#  7   job_time             474 non-null    float64
#  8   previous_experience  449 non-null    float64
#  9   minority             471 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 37.2+ KB
#                id   education         salary  starting_salary    job_time  \
# count  474.000000  474.000000     474.000000       474.000000  474.000000
# ...
